# %%
import utils
print(utils.__file__)
# Out:
# /home/dankrad/Desktop/Acoustic-Scattering-PINN/utils.py

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m mains.2D.phisk_training --model rff --hsave_dir ./checkpoints/2D/fisk/
# Out:
# Preloading weights for reference model
# Done!
# Collected 27303936/27303936 points...
# Total outside points generated: 27303936
# Collected 32768/32768 points...
# Total outside points generated: 32768
# Found 8 LoRA files: ['+0.7071068286895752+0.7071068286895752.pth', '+0.7071068286895752-0.7071068286895752.pth', '-1.0+1.2246468525851679e-16.pth', '-1.8369701465288538e-16-1.0.pth', '-0.7071068286895752+0.7071068286895752.pth', '-0.7071068286895752-0.7071068286895752.pth', '+1.0+0.0.pth', '+6.123234262925839e-17+1.0.pth']
# Incoming wave mode : plane
# Loading LoRA ensemble from checkpoints/2D/lora/
# Found 8 LoRA weight files
# Loading +0.7071068286895752+0.7071068286895752.pth
# Debug: LoRA state structure:
# net.0: dict with 3 keys
#   lora_A: tensor torch.Size([12, 512])
#   lora_B: tensor torch.Size([64, 12])
#   alpha: <class 'float'> = 1.0
# net.2: dict with 3 keys
#   lora_A: tensor torch.Size([12, 64])
#   lora_B: tensor torch.Size([64, 12])
# ...

# %%
# !python -m mains.3D.reference_training --model rff --save_dir ./checkpoints/3D/test/
# Out:
# Created trimesh sphere: trimesh_sphere.obj
#   Center: [0.0, 0.0, 0.0]
#   Radius: 0.2
#   Subdivisions: 8
#   Vertices: 655362
#   Faces: 1310720
#   Watertight: True
#   Volume: 0.033510
# Mesh: 655362 vertices, 1310720 faces
# Creating optimized 3D dataloaders...
#
# ...
# GENERATING ADAM PHASE POINTS
# ...
# Total generation time: 3.4304 seconds
# Final dataset: 17039360 outside points
# Distance range: [0.0000, 1.2962]
# All points satisfy radius constraint (>= 0.2000): False
# All points within box bounds: False
# Saved Adam points to: ./data_points/points_adams.pt
#
# ...
# GENERATING FINE-TUNING PHASE POINTS
# ...
# Total generation time: 0.4491 seconds
# Final dataset: 2818048 outside points
# Distance range: [0.0000, 1.2894]
# All points satisfy radius constraint (>= 0.2000): False
# All points within box bounds: False
# Saved fine-tuning points to: ./data_points/points_fine.pt
#
# Dataloader creation completed successfully!
# Loading 3D dataloaders from cache...
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0.dev20251221+cu128
